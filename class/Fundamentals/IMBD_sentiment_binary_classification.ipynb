# %% [markdown]
# It is highly recommended to use a powerful **GPU**, you can use it for free uploading this notebook to [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
# <table align="center">
#  <td align="center"><a target="_blank" href="https://colab.research.google.com/github/ezponda/intro_deep_learning/blob/main/class/Fundamentals/IMBD_sentiment_binary_classification.ipynb">
#         <img src="https://colab.research.google.com/img/colab_favicon_256px.png"  width="50" height="50" style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/IMBD_sentiment_binary_classification.ipynb">
#         <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png"  width="50" height="50" style="padding-bottom:5px;" />View Source on GitHub</a></td>
# </table>

# %% [markdown]
# # Classification Example
#  Two-class classification, or binary classification, may be the most widely applied kind of machine-learning problem. In this example, you’ll learn to classify movie reviews as positive or negative, based on the text content of the reviews.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
tf.random.set_seed(0)

# %% [markdown]
# ## The Dataset: The IMDB dataset
# We’ll work with the IMDB dataset: a set of 50,000 highly polarized reviews from the Internet Movie Database. They’re split into 25,000 reviews for training and 25,000 reviews for testing, each set consisting of 50% negative and 50% positive reviews. The  parameter `num_words` controls how many words different we want to use.

# %%
from tensorflow.keras.datasets import imdb
num_words = 5000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_words)
print(train_data[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 2, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 2, 19, 178, 32]

# %%
# Transform word_id to word and reverse
word2int = imdb.get_word_index()
word2int = {w: i+3 for w, i in word2int.items()}
word2int["<PAD>"] = 0
word2int["<START>"] = 1
word2int["<UNK>"] = 2
word2int["<UNUSED>"] = 3
int2word = {i: w for w, i in word2int.items()}
num_words = num_words+3

# %% [markdown]
# For transforming an id-sequence to a phrase use get_words

# %%
def get_words(sentence, int2word):
    return ' '.join([int2word.get(i,'<UNK>') for i in sentence])
print(get_words(train_data[0], int2word))
print('Sentiment: ', train_labels[0])
# Out:
# <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly <UNK> was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little <UNK> that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big <UNK> for the whole film but these children are amazing and should be <UNK> for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was <UNK> with us all
# Sentiment:  1

# %% [markdown]
# ## Data Preprocessing
#
# You need to convert your raw text to an appropriate input to a sequential model

# %%
def vectorize_text_sentence(text, word2int):
    tokens = text.split(' ')
    tokens_id = [word2int.get(tk,2) for tk in tokens]
    return tokens_id

text = get_words(train_data[0], int2word)
print(text)
print(vectorize_text_sentence(text, word2int))
# Out:
# <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly <UNK> was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little <UNK> that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big <UNK> for the whole film but these children are amazing and should be <UNK> for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was <UNK> with us all
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 2, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 2, 19, 178, 32]

# %% [markdown]
# ### Bag of Words Model BoW
# We are going to use a bag of words model. BoW is a simplifying representation used in natural language processing. In this model, a text (such as a sentence or a document) is represented as the Each key is the word, and each value is the frequency of occurrences of that word in the given text document.
#
# - **Input document**: `"John likes to watch movies Mary likes movies too"`
# - **BoW**: `{'John': 1, 'likes': 2, 'to': 1, 'watch': 1, 'movies': 2, 'Mary': 1, 'too': 1}`
# - **BoW Normalized**: `{'John': 0.11, 'likes': 0.22, 'to': 0.11, 'watch': 0.11, 'movies': 0.22, 'Mary': 0.11, 'too': 0.11}`

# %%
from collections import Counter

def get_bag_of_words(sequence, norm=True):
    word_count = Counter(sequence)
    if norm:
        total = sum(word_count.values())
        word_freq = {w: n / total for w, n in word_count.items()}
        return word_freq
    else:
        return dict(word_count.items())

text_example = "John likes to watch movies Mary likes movies too"
print('text_example', text_example)
text_sequence = text_example.split()
print('text splitted', text_sequence)
bag_of_words = get_bag_of_words(text_sequence)
print('bag_of_words', bag_of_words)
print('bag_of_words norm=False', get_bag_of_words(text_sequence, norm=False))
print(
    'bag_of_words with indexes', {
        word2int[w.lower()]: p
        for w, p in get_bag_of_words(text_sequence, norm=False).items()
    })
# Out:
# text_example John likes to watch movies Mary likes movies too
# text splitted ['John', 'likes', 'to', 'watch', 'movies', 'Mary', 'likes', 'movies', 'too']
# bag_of_words {'John': 0.1111111111111111, 'likes': 0.2222222222222222, 'to': 0.1111111111111111, 'watch': 0.1111111111111111, 'movies': 0.2222222222222222, 'Mary': 0.1111111111111111, 'too': 0.1111111111111111}
# bag_of_words norm=False {'John': 1, 'likes': 2, 'to': 1, 'watch': 1, 'movies': 2, 'Mary': 1, 'too': 1}
# bag_of_words with indexes {308: 1, 1232: 2, 8: 1, 106: 1, 102: 2, 1083: 1, 99: 1}

# %% [markdown]
# ### Document Term Matrix
#
# We need a way to model the documents so that they are all the same length, so that we can use a neural network. For this we are going to use the document term matrix.
# - Every document is a vector with the dimension of the vocabulary.
# - The position i of the vector corresponds to the word with index i.
# - The vector is all zeros except for the BoW word positions, which are filled with the frequency of the corresponding word.
#
#
# For example:
#
# - D1 = "I like movies",  `{'I': 1, 'like': 1, 'movies': 1}`
#
# - D2 = "I dislike movies",  `{'I': 1, 'dislike': 1, 'movies': 1}`
#
# Then the document-term matrix would be:
#
#
#
#    | Doc| I  | like    | dislike   | movies   |
# |---:|:-------------|:-----------|:------|:------|
# | D1 | 1  | 1       | 0   | 1     |
# | D2 | 1  | 0    | 1   | 1     |
#
# $D1 = [1,1,0,1]$
#
# $D2 = [1,0,1,1]$
#
# We convert every BoW to a vector of `dim=num_words` with `vectorize_sequences`

# %%
def vectorize_sequence(sequence, num_words, norm=True):
    vec = np.zeros(num_words)
    bow = get_bag_of_words(sequence, norm)
    for w, freq in bow.items():
        if w < num_words:
            vec[w] = freq
    return vec


def vectorize_sequences(sequences, num_words=num_words, norm=True):
    """Creates an all-zero matrix of shape (len(sequences), num_words)"""
    results = np.zeros((len(sequences), num_words))
    for i, sequence in enumerate(sequences):
        results[i, :] = vectorize_sequence(sequence, num_words, norm)
    return results


x_train = vectorize_sequences(train_data, num_words=num_words)
x_test = vectorize_sequences(test_data, num_words=num_words)
y_train =np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')
x_train.shape, y_train.shape
# Out:
# ((25000, 5003), (25000,))

# %% [markdown]
# ## Define and train a model
#
# Define, compile and fit your NN model
#
# 1. You can use the [Functional API](https://keras.io/guides/functional_api/):
#
# You need to start with an input data entry:
# ```python
#     inputs = keras.Input(shape=(8,))
#     layer_1 = layers.Dense(...)(inputs)
# ```
#
# and the network outputs:
# ```python
# outputs = layers.Dense(...)(previous_layer)
# model = keras.Model(inputs=inputs, outputs=outputs)
# ```
#
# 2. Or you can use [Sequential API](https://keras.io/guides/sequential_model/)
#
# ```python
# model = keras.Sequential(name='example_model')
# model.add(layers.Dense(..., input_shape=(8,))
# model.add(...
# ```
#
# You can introduce regularization methods seen in [Prevent_Overfitting.ipynb](https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/Prevent_Overfitting.ipynb) like [Dropout layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout):
#
#
# ```python
# tf.keras.layers.Dropout(
#     rate, noise_shape=None, seed=None, **kwargs
# )
# ```
#
# With Functional API:
# ```python
# next_layer = layers.Dropout(0.4)(prev_layer)
# ```
# With Sequential:
# ```python
# model.add(layers.Dropout(0.4))
# ```
#
# First try with only one hidden layer and see the results.

# %%
model = ...

# %%
inputs = tf.keras.Input(shape=(num_words,), name='input_layer')  # entrada
l_1 = layers.Dense(8, 'sigmoid')(inputs)
l_2 = layers.Dense(1, 'sigmoid')(l_1)
outputs = layers.Dense(1, 'sigmoid')(l_2)
# Model definition
model = keras.Model(inputs= inputs, outputs= outputs)

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # can be 'val_accuracy'
    patience=5,  # if during 5 epochs there is no improvement in `val_loss`, the execution will stop
    restore_best_weights=True,
    verbose=1)

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy'],
)
history = model.fit(x_train, y_train, validation_split=0.25, epochs= 10, batch_size=32, callbacks=[es_callback]
)
# Out:
# Epoch 1/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5006 - loss: 0.7057 - val_accuracy: 0.6395 - val_loss: 0.6922
# Epoch 2/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5916 - loss: 0.6919 - val_accuracy: 0.5181 - val_loss: 0.6911
# Epoch 3/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6342 - loss: 0.6905 - val_accuracy: 0.6957 - val_loss: 0.6890
# Epoch 4/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6861 - loss: 0.6881 - val_accuracy: 0.7622 - val_loss: 0.6850
# Epoch 5/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6752 - loss: 0.6832 - val_accuracy: 0.7512 - val_loss: 0.6772
# Epoch 6/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6966 - loss: 0.6738 - val_accuracy: 0.7557 - val_loss: 0.6630
# Epoch 7/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7340 - loss: 0.6576 - val_accuracy: 0.7696 - val_loss: 0.6413
# Epoch 8/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7699 - loss: 0.6335 - val_accuracy: 0.7814 - val_loss: 0.6127
# Epoch 9/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7926 - loss: 0.6027 - val_accuracy: 0.7978 - val_loss: 0.5798
# Epoch 10/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8093 - loss: 0.5681 - val_accuracy: 0.8098 - val_loss: 0.5454
# Restoring model weights from the end of the best epoch: 10.

# %%
import matplotlib.pyplot as plt
import pandas as pd
def show_loss_accuracy_evolution(hist):

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Sparse Categorical Crossentropy')
    ax1.plot(hist['epoch'], hist['loss'], label='Train Error')
    ax1.plot(hist['epoch'], hist['val_loss'], label = 'Val Error')
    ax1.grid()
    ax1.legend()

    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.plot(hist['epoch'], hist['accuracy'], label='Train Accuracy')
    ax2.plot(hist['epoch'], hist['val_accuracy'], label = 'Val Accuracy')
    ax2.grid()
    ax2.legend()

    plt.show()

hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
show_loss_accuracy_evolution(hist)

# %% [markdown]
# ### Evaluate the model
# You need to obtain a Test Accuracy > 0.85. Try to get more than 0.9!

# %%
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8021 - loss: 0.5464
# Test Loss: 0.5479320287704468
# Test Accuracy: 0.802839994430542

# %%
def show_errors(x_test, model, labels, int2word, n_samples=10):
    preds = 1.0 * (model.predict(x_test).flatten() > 0.5)
    bad_pred_inds = np.where(preds != labels)[0]
    n_samples = min(len(bad_pred_inds), n_samples)
    samples_inds = np.random.choice(bad_pred_inds, n_samples)
    for ind in samples_inds:
        print('Predicted : {0}, real : {1}, lenght: {2}'.format(
            int(preds[ind]), labels[ind], len(test_data[ind])))
        print(get_words(test_data[ind], int2word))
        print()
    return

show_errors(x_test, model, y_test, int2word, n_samples=10)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Predicted : 1, real : 0.0, lenght: 110
# <START> <UNK> is <UNK> worst film he has ever made it's full of his usual i e <UNK> dialogue brutal and sudden violence but it all <UNK> <UNK> the directing is typical <UNK> and nothing <UNK> new at all it's almost as if he's <UNK> exactly from his only masterpiece pulp fiction br br there is nothing new or exciting about <UNK> to be honest it's just a war drama that isn't funny nor brilliant as pulp fiction was <UNK> supposedly is <UNK> tribute to <UNK> <UNK> <UNK> but <UNK> <UNK> <UNK> and out of place especially with the <UNK> use of big sub titles and the audience of balance
#
# Predicted : 1, real : 0.0, lenght: 226
# <START> next stop on our journey through the <UNK> slasher scene is oh yes <UNK> day all of those <UNK> just <UNK> with possibility and ready to <UNK> out into the real world and become adults that is however if they can make it to <UNK> without having to <UNK> with the <UNK> <UNK> who's running around <UNK> the life out of students with his <UNK> sword yeah it all <UNK> from a the high school track star who drops dead from a blood <UNK> during a race and a year later her older sister returns home from the navy for <UNK> the track coach holds the blame and <UNK> in his position in shop class while the girl's boyfriend still <UNK> her death a year later all of these characters are prime <UNK> for serial slasher of the year and you just have to sit through this movie until the end to find out who done it <UNK> day is fun though it isn't spell original by any means and there aren't a whole lot of memorable <UNK> but there is enough going on to keep you mildly entertained like <UNK> <UNK> <UNK> the music teacher and getting <UNK> with a <UNK> 30 year old actors playing teenagers and of course gotta love that crap you can do a lot worse than <UNK> day <UNK>
#
# Predicted : 1, real : 0.0, lenght: 450
# <START> hitchcock is a great director ironically i mostly find his films a total waste of time to watch i admire <UNK> on a purely visual and technical level br br first the <UNK> hitchcock <UNK> the notion of the <UNK> camera the curious eye that is able to <UNK> or search for information it isn't exactly a new visual <UNK> but it was revolutionary then br br secondly hitchcock pretty much <UNK> the thriller and chase movie he has an <UNK> style and is always thinking of the audience he gives them regular thrills regular <UNK> of humour and regular <UNK> in short he <UNK> the <UNK> base needs and plays them like a <UNK> br br unfortunately the base needs of a human being are mostly stupid food sex the thrill of danger and a little comedy <UNK> for all these needs on screen with the exception of food which judging from his size he <UNK> to off screen br br it's this <UNK> to the audience that <UNK> most of his films a second <UNK> is that most of <UNK> camera work and visual <UNK> are now common place what keeps his films watchable are the simple <UNK> of his tales the intelligence of his camera work and his skill at <UNK> tense action set pieces br br so on to <UNK> this is a light hearted <UNK> in the <UNK> of the <UNK> steps it jumps from sequence to sequence until it <UNK> at the typical hitchcock final act set piece br br on an emotional level the relationship between the leads is not up to par with robert and <UNK> <UNK> in the <UNK> steps hence the whole story lacks a certain energy the plot simply <UNK> on like a machine desperately <UNK> on the addition of new scenes and new scenes only bring us <UNK> the end since it's not clear if the hook is the <UNK> escape from the police from the villains or his action to stop the <UNK> <UNK> br br there are the usual hitchcock logic flaws for example a guy with <UNK> <UNK> himself using a car fan <UNK> etc why doesn't he just drive away in the car surely <UNK> aren't that <UNK> he's able to <UNK> in them after all br br if you want a better hitchcock <UNK> propaganda flick from the <UNK> i would advise you watch foreign they are both silly chase movies with a catchy finale but foreign makes great use of <UNK> and <UNK> something spielberg <UNK> off nicely in <UNK> report br br 7 5 10 some good set pieces beyond that however there's nothing much to sink your teeth into
#
# Predicted : 1, real : 0.0, lenght: 284
# <START> enjoy the opening credits they're the best thing about this second rate but <UNK> time killer which features <UNK> performances from the likes of eric roberts and martin <UNK> the main part however goes to <UNK> tommy lee thomas who looks a bit <UNK> for this kind of action but who nevertheless occasionally manages to project a <UNK> kind of the first time we see him he's bare <UNK> <UNK> and engaged in that favorite <UNK> <UNK> <UNK> wood after this he has seven more scenes without his shirt including one in which he's <UNK> by his <UNK> and <UNK> with <UNK> a la mel <UNK> in <UNK> weapon he could use a better script however since the manner in which he <UNK> the truth about corruption and violence inside the prison is never very convincing there's also talk about millions of dollars which apparently is tied in with this investigation but which is never explained there are a few <UNK> though <UNK> john <UNK> <UNK> as john wilson is an amusing play on a <UNK> name and co star <UNK> <UNK> <UNK> shows promise as an <UNK> who early in the proceedings is shown <UNK> by his <UNK> and getting <UNK> by a <UNK> guard one final note the movie's low budget is painfully responsible for the lack of extras despite the impressive size of the prison it only seems to hold about 12 <UNK> note the cast credits at the end aren't too <UNK> for the record the <UNK> <UNK> headed guard who uses <UNK> <UNK> as a <UNK> bag is played by bill and the young fair <UNK> guard who <UNK> <UNK> to tommy lee thomas is played by <UNK>
#
# Predicted : 0, real : 1.0, lenght: 345
# <START> jack <UNK> 2 is probably the most <UNK> movie i have ever seen in my life the complete title of the film is jack <UNK> 2 revenge of the <UNK> killer <UNK> horror movie fans that have a taste for campy story lines will be <UNK> to watch this this film was straight to video and for good reasons here's why the acting was so atrocious and so terrible that it could cause one to cry the main character had no personality and the <UNK> bad acting made it all worse the screenplay was was also atrocious each character always says a cheesy line and add the cheesy lines to the bad choreography then you have something bad second the story line isn't really all that impressive but since this movie was straight to video it is <UNK> the director and writer could have turned the idea of a killer <UNK> into something cool but they didn't they story has lots of plot holes in it in the beginning a cup of coffee gets <UNK> into the fish <UNK> with the <UNK> jack <UNK> scientists try to <UNK> his life but they couldn't once the cup of coffee fell into the <UNK> jack <UNK> was completely restored now he is <UNK> to anti <UNK> in jack <UNK> part 1 the main character's <UNK> got mixed up with the anti <UNK> that was used to kill jack <UNK> since the main character is <UNK> to <UNK> jack <UNK> is too hence here's my point they say that <UNK> <UNK> combined with jack <UNK> but one of the scientists had some <UNK> on the cup so when it fell into the <UNK> the scientists <UNK> would have been combined with jack another thing the special effects weren't very good either here's the good points jack <UNK> 2 has lots of blood that looks pretty realistic even though this movie is flawed to hell it is still entertaining overall jack <UNK> 2 is an enjoyable horror movie the first one was better though 7 out of 10
#
# Predicted : 0, real : 1.0, lenght: 115
# <START> good boring or bad it's good worth your money if you can spare it for a ticket sure better than the trailer makes it seem yes oddly br br there isn't much to the script <UNK> working at <UNK> truck company move vast amounts of cash <UNK> see opportunity to <UNK> as <UNK> one of them is too honest to go along with it all and a well laid plan goes to hell br br this could have been a poorly executed <UNK> dogs <UNK> but the skill of the cast and the director's ability to make just about anything tense pull it out of that <UNK> and put it onto a solid <UNK>
#
# Predicted : 1, real : 0.0, lenght: 464
# <START> there was a time when <UNK> <UNK> was <UNK> quite high on my list of favorite directors back in the late 80's and early 90's when his name was attached to several great films like the lost boys and falling down he truly was one of the most gifted directors in hollywood then came the stupid batman sequels unfortunately and after that it seemed as if every potentially <UNK> screenplay turned into a <UNK> mess in <UNK> hands both <UNK> and phone <UNK> could have been much better films and even the incredibly <UNK> concept of the number <UNK> should have been <UNK> into a slightly more compelling and entertaining movie literally from start to finish the number <UNK> desperately attempts to be a mysterious and <UNK> thriller and therefore uses all the dreadful clichés from the big book of cinema history including heavy voiced narration flashbacks <UNK> structure characters with multiple personalities numerous plot twists that grow increasingly absurd and sinister <UNK> settings nothing helps however simply due to the sheer <UNK> of the basic formula and the clearly uninspired <UNK> of cast crew as much as you try to <UNK> with the lead character and be open minded regarding the insane <UNK> this still remains a movie about a two <UNK> number and two <UNK> numbers aren't scary walter <UNK> jim carrey in a rare non comical role is a bored animal <UNK> whose wife <UNK> gives him a bizarre book on his birthday the book tells about all sorts of <UNK> <UNK> and strange <UNK> that are <UNK> to the number <UNK> walter almost <UNK> <UNK> himself with the <UNK> protagonist a sleazy detective <UNK> a grim case of suicide and begins to spot <UNK> examples of the <UNK> <UNK> in his own private life i did some research on <UNK> and <UNK> and apparently this whole <UNK> <UNK> nonsense really exists and certain people honestly believe that most <UNK> and <UNK> are directly connected to this evil number well that's just <UNK> crazy but hey i'm not here to judge people's beliefs and fears regardless of how demented they are and i can only share my humble opinion on a movie that is based on an out and out <UNK> <UNK> the number <UNK> is not suspenseful in spite of several <UNK> set pieces and nasty make up effects and never at one point manages to make you <UNK> about the role of numbers in your own life all cast members perform below their normal <UNK> but it was still nevertheless a joy to see the lovely mrs virginia <UNK> in a relatively big production again definitely not recommended in case you're looking for a solid and creepy evening of thriller fun but <UNK> and not entirely without merit
#
# Predicted : 0, real : 1.0, lenght: 198
# <START> the <UNK> has been <UNK> in many different ways <UNK> from more or less traditional views as dealing with art to more post modern <UNK> that like to <UNK> the play along post <UNK> feminist gender or lines the reason why version left me fairly cold is that i didn't have a clue what he was on about what is the <UNK> vision idea concept behind this <UNK> of shakespeare the previous reviewers do not get much further than revenge tragedy punk show but surely there is more to it isn't there this is not to say that there is no vision here just that i was hard put to discover it be that as it may there are still things to enjoy the punk <UNK> is refreshing and funny <UNK> as <UNK> and jack as are wonderful i did not much care about williams as <UNK> not enough magic i suppose the <UNK> between the old <UNK> castle and the very english world outside can be a little unsettling at times but i guess that is <UNK> all in all interesting but not quite the success i had hoped it might be particularly after seeing <UNK>
#
# Predicted : 0, real : 1.0, lenght: 135
# <START> i consider myself a huge horror movie fan one night i wanted to just rent some <UNK> horror movies to make fun of then i rented <UNK> i was so surprised by this movie it scared the hell <UNK> me that's not something i can say very often usually halloween only scares me br br two other friends watched it with me and were left with a disturbed feeling a good feeling if you ask me after watching a horror movie if you are <UNK> then what's the point br br this movie was original it didn't follow the normal <UNK> of a horror movie that's why movies like <UNK> <UNK> for me br br of course many are left with <UNK> questions as most horror movies do it is worth the rent though
#
# Predicted : 0, real : 1.0, lenght: 148
# <START> no blood no sex though it <UNK> passion no special effects but just one of those <UNK> that comes across your movie screen when you're not really looking and <UNK> your attention br br great acting great sets great music beautiful storyline if only there were a lot more movies made like this one br br the sets move us through time and make us feel like we were there br br the acting appears like real life and <UNK> us to the level of <UNK> of <UNK> to whom no one is a lost cause least of all the <UNK> of her own halfway house br br best of all it's a true story of <UNK> learning to fit in i was somewhat jealous of the good times that everyone appeared to be having in the movie could we all spend some time in <UNK> house

# %% [markdown]
# ### Making predictioins with new data

# %%
reviews = ['the film was really bad and i am very disappointed',
           'The film was very funny entertaining and good we had a great time . brilliant film',
           'this film was just brilliant',
           'the movie is not bad',
           'the movie is not bad I like it'
]
sequences = [vectorize_text_sentence(review.lower(), word2int)
             for review in reviews]

x_pred = vectorize_sequences(sequences, num_words=num_words)
predictions = model.predict(x_pred)
for review, pred in zip(reviews, predictions.flatten()):
    print()
    print(review)
    print('Sentiment: ', np.round(pred, 2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
#
# the film was really bad and i am very disappointed
# Sentiment:  0.29
#
# The film was very funny entertaining and good we had a great time . brilliant film
# Sentiment:  0.74
#
# this film was just brilliant
# Sentiment:  0.21
#
# the movie is not bad
# Sentiment:  0.11
#
# the movie is not bad I like it
# Sentiment:  0.14

# %%
1.0*(model.predict(x_pred) > 0.5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# array([[0.],
#        [1.],
#        [0.],
#        [0.],
#        [0.]])

# %% [markdown]
# ### Question 1: Repeat the process with unnormalized bag of words, compare results

# %%
x_train = vectorize_sequences(train_data, num_words=num_words, norm=False)
x_test = vectorize_sequences(test_data, num_words=num_words, norm=False)
y_train =np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')
x_train.shape, y_train.shape
# Out:
# ((25000, 5003), (25000,))

# %%
model = ...

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
history = model.fit(x_train, y_train, validation_split=0.25, epochs= 10, batch_size=32)
show_loss_accuracy_evolution(hist)
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Epoch 1/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8212 - loss: 0.4814 - val_accuracy: 0.8173 - val_loss: 0.4589
# Epoch 2/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8330 - loss: 0.4352 - val_accuracy: 0.8214 - val_loss: 0.4345
# Epoch 3/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8419 - loss: 0.4135 - val_accuracy: 0.8245 - val_loss: 0.4206
# Epoch 4/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8484 - loss: 0.3974 - val_accuracy: 0.8317 - val_loss: 0.4103
# Epoch 5/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8556 - loss: 0.3831 - val_accuracy: 0.8382 - val_loss: 0.4001
# Epoch 6/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8606 - loss: 0.3710 - val_accuracy: 0.8421 - val_loss: 0.3932
# Epoch 7/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8651 - loss: 0.3606 - val_accuracy: 0.8464 - val_loss: 0.3870
# Epoch 8/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8691 - loss: 0.3512 - val_accuracy: 0.8491 - val_loss: 0.3818
# Epoch 9/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8725 - loss: 0.3424 - val_accuracy: 0.8517 - val_loss: 0.3782
# Epoch 10/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8764 - loss: 0.3348 - val_accuracy: 0.8530 - val_loss: 0.3737
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8491 - loss: 0.3792
# Test Loss: 0.379415363073349
# Test Accuracy: 0.8482800126075745

# %% [markdown]
# ### Question 2: What happens if you reduce the size of the vocabulary `num_words`, compare results

# %%
num_words = 5000
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=num_words)
print(train_data[0])

word2int = imdb.get_word_index()
word2int = {w: i+3 for w, i in word2int.items()}
word2int["<PAD>"] = 0
word2int["<START>"] = 1
word2int["<UNK>"] = 2
word2int["<UNUSED>"] = 3
int2word = {i: w for w, i in word2int.items()}
num_words = num_words+3

x_train = vectorize_sequences(train_data, num_words=num_words)
x_test = vectorize_sequences(test_data, num_words=num_words)
y_train =np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')
x_train.shape, y_train.shape
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 2, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 2, 19, 178, 32]
# ((25000, 5003), (25000,))

# %%
model = ...

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
history = model.fit(x_train, y_train, validation_split=0.25, epochs= 10, batch_size=32)
show_loss_accuracy_evolution(hist)
results = model.evaluate(x_test, y_test, verbose=1)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Epoch 1/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7702 - loss: 0.5206 - val_accuracy: 0.8451 - val_loss: 0.4766
# Epoch 2/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8556 - loss: 0.4613 - val_accuracy: 0.8494 - val_loss: 0.4492
# Epoch 3/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8601 - loss: 0.4331 - val_accuracy: 0.8538 - val_loss: 0.4246
# Epoch 4/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8646 - loss: 0.4079 - val_accuracy: 0.8594 - val_loss: 0.4033
# Epoch 5/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8684 - loss: 0.3859 - val_accuracy: 0.8616 - val_loss: 0.3852
# Epoch 6/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8726 - loss: 0.3670 - val_accuracy: 0.8650 - val_loss: 0.3700
# Epoch 7/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8760 - loss: 0.3509 - val_accuracy: 0.8669 - val_loss: 0.3572
# Epoch 8/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8783 - loss: 0.3370 - val_accuracy: 0.8683 - val_loss: 0.3464
# Epoch 9/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8814 - loss: 0.3250 - val_accuracy: 0.8685 - val_loss: 0.3372
# Epoch 10/10
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8840 - loss: 0.3144 - val_accuracy: 0.8696 - val_loss: 0.3294
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8691 - loss: 0.3333
# Test Loss: 0.3334013819694519
# Test Accuracy: 0.8690800070762634

# %%
reviews = [
    'the film was really bad and i am very disappointed',
    'The film was very funny entertaining and good we had a great time . brilliant film',
    'this film was just brilliant', 'the movie is not bad',
    'the movie is not bad I like it'
]
sequences = [
    vectorize_text_sentence(review.lower(), word2int) for review in reviews
]

x_pred = vectorize_sequences(sequences, num_words=num_words)
predictions = model.predict(x_pred)
for review, pred in zip(reviews, predictions.flatten()):
    print()
    print(review)
    print('Sentiment: ', np.round(pred, 2))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
#
# the film was really bad and i am very disappointed
# Sentiment:  0.03
#
# The film was very funny entertaining and good we had a great time . brilliant film
# Sentiment:  0.96
#
# this film was just brilliant
# Sentiment:  0.4
#
# the movie is not bad
# Sentiment:  0.01
#
# the movie is not bad I like it
# Sentiment:  0.01

# %% [markdown]
# ### Compare with other ML algorithms

# %%
from sklearn.linear_model import LogisticRegression
clr = LogisticRegression()
clr.fit(x_train, y_train)
val_acc = clr.score(x_test, y_test)
print('Test Accuracy: {}'.format(val_acc))
# Out:
# Test Accuracy: 0.71792

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth=5, n_jobs=-1)
rfc.fit(x_train, y_train)
val_acc = rfc.score(x_test, y_test)
print('Test Accuracy: {}'.format(val_acc))
# Out:
# Test Accuracy: 0.8038

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_jobs=-1)
rfc.fit(x_train, y_train)
val_acc = rfc.score(x_test, y_test)
print('Test Accuracy: {}'.format(val_acc))
# Out:
# Test Accuracy: 0.84116

# %%
reviews = []
# training reviews
for ind in range(len(train_data)):
    sentence = train_data[ind]
    sentence_text = get_words(train_data[ind], int2word)
    reviews.append(sentence_text)
print('First training review: ', reviews[0])
# Out:
# First training review:  <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly <UNK> was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little <UNK> that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big <UNK> for the whole film but these children are amazing and should be <UNK> for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was <UNK> with us all
