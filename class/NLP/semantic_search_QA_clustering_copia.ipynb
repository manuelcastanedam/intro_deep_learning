# %% [markdown]
# It is highly recommended to use a powerful **GPU**, you can use it for free uploading this notebook to [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
# <table align="center">
#  <td align="center"><a target="_blank" href="https://colab.research.google.com/github/ezponda/intro_deep_learning/blob/main/class/NLP/semantic_search_QA_clustering.ipynb">
#         <img src="https://colab.research.google.com/img/colab_favicon_256px.png"  width="50" height="50" style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/ezponda/intro_deep_learning/blob/main/class/NLP/semantic_search_QA_clustering.ipynb">
#         <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png"  width="50" height="50" style="padding-bottom:5px;" />View Source on GitHub</a></td>
# </table>

# %% [markdown]
# # Semantic search & QA
#
# In this notebook, we'll introduce semantic search and question-answering using [`sentence-transformers`](https://www.sbert.net/), a Python library for state-of-the-art sentence, text and image embeddings. These embeddings are useful for semantic similarity tasks, such as information retrieval and question-answering systems.

# %%
# Install the sentence-transformers library
#!pip install -U sentence-transformers

# %%
import json
from sentence_transformers import SentenceTransformer, CrossEncoder, util
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd
import time
import gzip
import os
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# We'll use a pre-trained Sentence Transformer model to generate sentence embeddings. Many pre-trained models are available [here](https://www.sbert.net/docs/pretrained_models.html)

# %%
model_name = 'all-MiniLM-L6-v2'
model = SentenceTransformer(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# For our semantic search and question-answering task, we need a list of documents or paragraphs to search through for relevant information.

# %%
# Sample paragraphs
paragraphs = [
    "The Eiffel Tower is a wrought-iron lattice tower on the Champ de Mars in Paris, France.",
    "The Statue of Liberty is a colossal neoclassical sculpture on Liberty Island in New York Harbor within New York City, in the United States.",
    "The Great Wall of China is a series of fortifications made of stone, brick, tamped earth, wood, and other materials, generally built along an east-to-west line across the historical northern borders of China.",
    "The Colosseum, also known as the Flavian Amphitheatre, is an oval amphitheatre in the centre of the city of Rome, Italy.",
    "The Taj Mahal is an ivory-white marble mausoleum on the southern bank of the river Yamuna in the Indian city of Agra."
]

paragraphs = np.array(paragraphs)

# %%
# Generate embeddings for paragraphs
corpus_embeddings = model.encode(paragraphs)
print(corpus_embeddings.shape)
# Out:
# (5, 384)

# %% [markdown]
# Now, let's define a function to perform semantic search, given a query and a list of paragraph embeddings.

# %%
def semantic_search(query, model, corpus_embeddings, paragraphs, top_k=2):
    query_embedding = model.encode([query])[0]
    similarities = cosine_similarity([query_embedding], corpus_embeddings)[0]
    indexes = np.argpartition(similarities, -top_k)[-top_k:]
    indexes = indexes[np.argsort(-similarities[indexes])]
    print(f"Input query: {query}")
    print()
    for text, sim in zip(list(paragraphs[indexes]), similarities[indexes].tolist()):
        print(f"{sim:.3f}\t{text}")


semantic_search('Where is the Colosseum', model, corpus_embeddings, paragraphs, top_k=2)
# Out:
# Input query: Where is the Colosseum
#
# 0.801	The Colosseum, also known as the Flavian Amphitheatre, is an oval amphitheatre in the centre of the city of Rome, Italy.
# 0.226	The Taj Mahal is an ivory-white marble mausoleum on the southern bank of the river Yamuna in the Indian city of Agra.

# %% [markdown]
# ## Multilingual models

# %%
# lets try in other languages
semantic_search('¿Dónde está el Coliseo?', model, corpus_embeddings, paragraphs, top_k=2)
# Out:
# Input query: ¿Dónde está el Coliseo?
#
# 0.086	The Statue of Liberty is a colossal neoclassical sculpture on Liberty Island in New York Harbor within New York City, in the United States.
# 0.067	The Taj Mahal is an ivory-white marble mausoleum on the southern bank of the river Yamuna in the Indian city of Agra.

# %% [markdown]
# We have multilinguals models available [here](https://www.sbert.net/docs/pretrained_models.html#multi-lingual-models)

# %%
# we can use multilingual models
model_name = 'paraphrase-multilingual-MiniLM-L12-v2'
multi_model = SentenceTransformer(model_name)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.12k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
multi_corpus_embeddings = multi_model.encode(paragraphs)
print(multi_corpus_embeddings.shape)
# Out:
# (5, 384)

# %%
semantic_search('¿Dónde está el Coliseo?', multi_model, multi_corpus_embeddings, paragraphs, top_k=2)
# Out:
# Input query: ¿Dónde está el Coliseo?
#
# 0.439	The Colosseum, also known as the Flavian Amphitheatre, is an oval amphitheatre in the centre of the city of Rome, Italy.
# 0.299	The Statue of Liberty is a colossal neoclassical sculpture on Liberty Island in New York Harbor within New York City, in the United States.

# %% [markdown]
# ## Wikipedia semantic search
#
# As dataset, we use Simple English Wikipedia. Compared to the full English wikipedia, it has only
# about 170k articles. We split these articles into paragraphs

# %%
wikipedia_filepath = 'data/simplewiki-2020-11-01.jsonl.gz'

if not os.path.exists(wikipedia_filepath):
    util.http_get('http://sbert.net/datasets/simplewiki-2020-11-01.jsonl.gz', wikipedia_filepath)

passages = []
with gzip.open(wikipedia_filepath, 'rt', encoding='utf8') as fIn:
    for line in fIn:
        data = json.loads(line.strip())
        for paragraph in data['paragraphs']:
            # We encode the passages as [title, text]
            passages.append(data['title']+':  '+ paragraph)

# If you like, you can also limit the number of passages you want to use
print("Passages:", len(passages))
print(passages[0])
print(passages[1])
# Out:
#   0%|          | 0.00/50.2M [00:00<?, ?B/s]
# Passages: 509663
# Ted Cassidy:  Ted Cassidy (July 31, 1932 - January 16, 1979) was an American actor. He was best known for his roles as Lurch and Thing on "The Addams Family".
# Aileen Wuornos:  Aileen Carol Wuornos Pralle (born Aileen Carol Pittman; February 29, 1956 – October 9, 2002) was an American serial killer. She was born in Rochester, Michigan. She confessed to killing six men in Florida and was executed in Florida State Prison by lethal injection for the murders. Wuornos said that the men she killed had raped her or tried to rape her while she was working as a prostitute.

# %%
reduced_passages = np.array(passages[:5000])
reduced_passages.shape
# Out:
# (5000,)

# %%
corpus_embeddings = model.encode(reduced_passages, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/157 [00:00<?, ?it/s]

# %%
semantic_search('Best american actor', model, corpus_embeddings, reduced_passages, top_k=2)
# Out:
# Input query: Best american actor
#
# 0.539	Aaron Kwok:  Aaron won the Best Actor Award again at the forty-third Golden Horse Awards on 24 November 2006 for his role in the movie "After This Our Exile". He became the second actor in the history of the Golden Horse Awards to win the Best Actor Award year after year. Jackie Chan first achieved this back in the 1990s.
# 0.425	James L. Brooks:  He is best known for creating American television programs such as "The Mary Tyler Moore Show", "The Simpsons", "Rhoda" and "Taxi". His best-known movie is "Terms of Endearment", for which he received three Academy Awards in 1984.

# %%
semantic_search('Number countries Europe', model, corpus_embeddings, reduced_passages, top_k=2)
# Out:
# Input query: Number countries Europe
#
# 0.502	European Union member state:  A European Union member state is any one of the twenty-seven countries that have joined the European Union (EU) since it was found in 1958 as the European Economic Community (EEC). From an original membership of six states, there have been five successive enlargements. The largest happened on 1 May 2004, when ten member states joined.
# 0.465	European Space Agency:  The member countries of ESA are Austria, Belgium, Czech Republic, Denmark, Finland, France, Germany, Greece, Ireland, Italy, Luxembourg, the Netherlands, Norway, Portugal, Spain, Sweden, Switzerland and the United Kingdom.

# %% [markdown]
# ### Question1: Load a different pre-trained Sentence Transformer model and compare its performance to the last model on the same set of paragraphs and queries. Which model performs better?

# %%
# Load a different pre-trained model, generate embeddings, and test with the same queries
model_name = 'paraphrase-multilingual-mpnet-base-v2'
new_model = SentenceTransformer(model_name)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.13k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ## Question 2: Find text duplicates
#
# Try to find duplicate or near-duplicate texts in a given corpus based on their semantic similarity using sentence-transformers.

# %%
corpus = [
    "The quick brown fox jumps over the lazy dog.",
    "The quick brown fox leaps over the lazy dog.",
    "The sky is blue, and the grass is green.",
    "The grass is green, and the sky is blue.",
    "It's a sunny day today.",
    "The weather is sunny today.",
    "She was wearing a beautiful red dress.",
    "She had on a gorgeous red dress.",
    "I'm going to the supermarket to buy some groceries.",
    "I'm heading to the supermarket to purchase some groceries.",
    "He didn't like the movie because it was too long.",
    "He disliked the movie as it was too lengthy.",
    "The train was delayed due to technical issues.",
    "Technical issues caused the train to be delayed.",
    "I'll have a cup of coffee with milk and sugar, please.",
    "Can I get a coffee with milk and sugar, please?",
    "The conference was very informative and interesting.",
    "The conference turned out to be interesting and informative.",
    "He enjoys listening to classical music in his free time.",
    "In his leisure time, he likes to listen to classical music.",
    "Please make sure you turn off the lights before leaving.",
    "Before leaving, ensure that you switch off the lights.",
    "The boy was delighted with the gift he received.",
    "Receiving the present made the young lad ecstatic.",
    "She has a preference for Italian cuisine.",
    "Her favorite type of food is from Italy.",
    "The software engineer resolved the issue by modifying the code.",
    "By altering the programming, the tech expert fixed the problem.",
    "Due to the inclement weather, the baseball game was postponed.",
    "The baseball match was rescheduled because of bad weather conditions.",
    "The house was engulfed in a raging fire.",
    "Flames rapidly consumed the residence.",
    "He is constantly browsing the internet for the latest news.",
    "He frequently scours the web to stay updated on current events.",
    "The puppy was playing with a toy in the garden.",
    "In the yard, the young dog was frolicking with its plaything.",
    "The artist painted a beautiful landscape on the canvas.",
]

# %%
# Step 1: Initialize the SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# Step 2: Obtain corpus embeddings
embeddings = model.encode(corpus)
embeddings.shape
# Out:
# (37, 384)

# %%
# Step 3: Calculate similarity and find duplicates

# TODO: Define a similarity threshold
similarity_threshold = 0.8 # Example value

# TODO: Iterate over each pair of embeddings in the corpus
# Calculate the cosine similarity between the embeddings
# If the similarity is above the threshold, add the sentences to the duplicates list
duplicates = []

for i, emb1 in enumerate(embeddings):
    for j, emb2 in enumerate(embeddings[i + 1:]):
        similarity = cosine_similarity([emb1], [emb2])[0][0]
        if ...:
            duplicates.append((corpus[i], corpus[i + j + 1], similarity))

# %%
print("Duplicate sentences:")
for sent1, sent2, sim in duplicates:
    print(f"{sent1} | {sent2} | Similarity: {sim:.2f}")
    print()
# Out:
# Duplicate sentences:
# The quick brown fox jumps over the lazy dog. | The quick brown fox leaps over the lazy dog. | Similarity: 0.98
#
# The quick brown fox jumps over the lazy dog. | The sky is blue, and the grass is green. | Similarity: 0.14
#
# The quick brown fox jumps over the lazy dog. | The grass is green, and the sky is blue. | Similarity: 0.14
#
# The quick brown fox jumps over the lazy dog. | It's a sunny day today. | Similarity: 0.13
#
# The quick brown fox jumps over the lazy dog. | The weather is sunny today. | Similarity: 0.10
#
# The quick brown fox jumps over the lazy dog. | She was wearing a beautiful red dress. | Similarity: 0.03
#
# The quick brown fox jumps over the lazy dog. | She had on a gorgeous red dress. | Similarity: 0.05
#
# The quick brown fox jumps over the lazy dog. | I'm going to the supermarket to buy some groceries. | Similarity: 0.10
#
# The quick brown fox jumps over the lazy dog. | I'm heading to the supermarket to purchase some groceries. | Similarity: 0.11
#
# The quick brown fox jumps over the lazy dog. | He didn't like the movie because it was too long. | Similarity: 0.01
#
# The quick brown fox jumps over the lazy dog. | He disliked the movie as it was too lengthy. | Similarity: -0.00
#
# The quick brown fox jumps over the lazy dog. | The train was delayed due to technical issues. | Similarity: 0.08
#
# The quick brown fox jumps over the lazy dog. | Technical issues caused the train to be delayed. | Similarity: 0.10
#
# The quick brown fox jumps over the lazy dog. | I'll have a cup of coffee with milk and sugar, please. | Similarity: 0.05
#
# The quick brown fox jumps over the lazy dog. | Can I get a coffee with milk and sugar, please? | Similarity: 0.04
#
# The quick brown fox jumps over the lazy dog. | The conference was very informative and interesting. | Similarity: 0.00
#
# The quick brown fox jumps over the lazy dog. | The conference turned out to be interesting and informative. | Similarity: 0.02
#
# The quick brown fox jumps over the lazy dog. | He enjoys listening to classical music in his free time. | Similarity: 0.01
#
# The quick brown fox jumps over the lazy dog. | In his leisure time, he likes to listen to classical music. | Similarity: 0.03
#
# The quick brown fox jumps over the lazy dog. | Please make sure you turn off the lights before leaving. | Similarity: 0.03
#
# The quick brown fox jumps over the lazy dog. | Before leaving, ensure that you switch off the lights. | Similarity: 0.04
#
# The quick brown fox jumps over the lazy dog. | The boy was delighted with the gift he received. | Similarity: 0.03
#
# The quick brown fox jumps over the lazy dog. | Receiving the present made the young lad ecstatic. | Similarity: 0.08
#
# The quick brown fox jumps over the lazy dog. | She has a preference for Italian cuisine. | Similarity: -0.00
#
# The quick brown fox jumps over the lazy dog. | Her favorite type of food is from Italy. | Similarity: 0.03
#
# The quick brown fox jumps over the lazy dog. | The software engineer resolved the issue by modifying the code. | Similarity: 0.05
#
# The quick brown fox jumps over the lazy dog. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.02
#
# The quick brown fox jumps over the lazy dog. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.03
#
# The quick brown fox jumps over the lazy dog. | The baseball match was rescheduled because of bad weather conditions. | Similarity: -0.01
#
# The quick brown fox jumps over the lazy dog. | The house was engulfed in a raging fire. | Similarity: 0.08
#
# The quick brown fox jumps over the lazy dog. | Flames rapidly consumed the residence. | Similarity: 0.07
#
# The quick brown fox jumps over the lazy dog. | He is constantly browsing the internet for the latest news. | Similarity: 0.12
#
# The quick brown fox jumps over the lazy dog. | He frequently scours the web to stay updated on current events. | Similarity: 0.05
#
# The quick brown fox jumps over the lazy dog. | The puppy was playing with a toy in the garden. | Similarity: 0.17
#
# The quick brown fox jumps over the lazy dog. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.33
#
# The quick brown fox jumps over the lazy dog. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.04
#
# The quick brown fox leaps over the lazy dog. | The sky is blue, and the grass is green. | Similarity: 0.16
#
# The quick brown fox leaps over the lazy dog. | The grass is green, and the sky is blue. | Similarity: 0.16
#
# The quick brown fox leaps over the lazy dog. | It's a sunny day today. | Similarity: 0.15
#
# The quick brown fox leaps over the lazy dog. | The weather is sunny today. | Similarity: 0.10
#
# The quick brown fox leaps over the lazy dog. | She was wearing a beautiful red dress. | Similarity: 0.04
#
# The quick brown fox leaps over the lazy dog. | She had on a gorgeous red dress. | Similarity: 0.06
#
# The quick brown fox leaps over the lazy dog. | I'm going to the supermarket to buy some groceries. | Similarity: 0.11
#
# The quick brown fox leaps over the lazy dog. | I'm heading to the supermarket to purchase some groceries. | Similarity: 0.13
#
# The quick brown fox leaps over the lazy dog. | He didn't like the movie because it was too long. | Similarity: 0.03
#
# The quick brown fox leaps over the lazy dog. | He disliked the movie as it was too lengthy. | Similarity: 0.02
#
# The quick brown fox leaps over the lazy dog. | The train was delayed due to technical issues. | Similarity: 0.06
#
# The quick brown fox leaps over the lazy dog. | Technical issues caused the train to be delayed. | Similarity: 0.09
#
# The quick brown fox leaps over the lazy dog. | I'll have a cup of coffee with milk and sugar, please. | Similarity: 0.07
#
# The quick brown fox leaps over the lazy dog. | Can I get a coffee with milk and sugar, please? | Similarity: 0.04
#
# The quick brown fox leaps over the lazy dog. | The conference was very informative and interesting. | Similarity: 0.01
#
# The quick brown fox leaps over the lazy dog. | The conference turned out to be interesting and informative. | Similarity: 0.04
#
# The quick brown fox leaps over the lazy dog. | He enjoys listening to classical music in his free time. | Similarity: 0.02
#
# The quick brown fox leaps over the lazy dog. | In his leisure time, he likes to listen to classical music. | Similarity: 0.04
#
# The quick brown fox leaps over the lazy dog. | Please make sure you turn off the lights before leaving. | Similarity: 0.05
#
# The quick brown fox leaps over the lazy dog. | Before leaving, ensure that you switch off the lights. | Similarity: 0.05
#
# The quick brown fox leaps over the lazy dog. | The boy was delighted with the gift he received. | Similarity: 0.07
#
# The quick brown fox leaps over the lazy dog. | Receiving the present made the young lad ecstatic. | Similarity: 0.09
#
# The quick brown fox leaps over the lazy dog. | She has a preference for Italian cuisine. | Similarity: 0.02
#
# The quick brown fox leaps over the lazy dog. | Her favorite type of food is from Italy. | Similarity: 0.04
#
# The quick brown fox leaps over the lazy dog. | The software engineer resolved the issue by modifying the code. | Similarity: 0.05
#
# The quick brown fox leaps over the lazy dog. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.04
#
# The quick brown fox leaps over the lazy dog. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.02
#
# The quick brown fox leaps over the lazy dog. | The baseball match was rescheduled because of bad weather conditions. | Similarity: -0.01
#
# The quick brown fox leaps over the lazy dog. | The house was engulfed in a raging fire. | Similarity: 0.09
#
# The quick brown fox leaps over the lazy dog. | Flames rapidly consumed the residence. | Similarity: 0.09
#
# The quick brown fox leaps over the lazy dog. | He is constantly browsing the internet for the latest news. | Similarity: 0.13
#
# The quick brown fox leaps over the lazy dog. | He frequently scours the web to stay updated on current events. | Similarity: 0.07
#
# The quick brown fox leaps over the lazy dog. | The puppy was playing with a toy in the garden. | Similarity: 0.18
#
# The quick brown fox leaps over the lazy dog. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.35
#
# The quick brown fox leaps over the lazy dog. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.07
#
# The sky is blue, and the grass is green. | The grass is green, and the sky is blue. | Similarity: 0.99
#
# The sky is blue, and the grass is green. | It's a sunny day today. | Similarity: 0.42
#
# The sky is blue, and the grass is green. | The weather is sunny today. | Similarity: 0.42
#
# The sky is blue, and the grass is green. | She was wearing a beautiful red dress. | Similarity: 0.07
#
# The sky is blue, and the grass is green. | She had on a gorgeous red dress. | Similarity: 0.08
#
# The sky is blue, and the grass is green. | I'm going to the supermarket to buy some groceries. | Similarity: 0.14
#
# The sky is blue, and the grass is green. | I'm heading to the supermarket to purchase some groceries. | Similarity: 0.17
#
# The sky is blue, and the grass is green. | He didn't like the movie because it was too long. | Similarity: 0.01
#
# The sky is blue, and the grass is green. | He disliked the movie as it was too lengthy. | Similarity: -0.01
#
# The sky is blue, and the grass is green. | The train was delayed due to technical issues. | Similarity: -0.03
#
# The sky is blue, and the grass is green. | Technical issues caused the train to be delayed. | Similarity: -0.01
#
# The sky is blue, and the grass is green. | I'll have a cup of coffee with milk and sugar, please. | Similarity: 0.11
#
# The sky is blue, and the grass is green. | Can I get a coffee with milk and sugar, please? | Similarity: 0.04
#
# The sky is blue, and the grass is green. | The conference was very informative and interesting. | Similarity: 0.03
#
# The sky is blue, and the grass is green. | The conference turned out to be interesting and informative. | Similarity: 0.04
#
# The sky is blue, and the grass is green. | He enjoys listening to classical music in his free time. | Similarity: 0.09
#
# The sky is blue, and the grass is green. | In his leisure time, he likes to listen to classical music. | Similarity: 0.13
#
# The sky is blue, and the grass is green. | Please make sure you turn off the lights before leaving. | Similarity: 0.12
#
# The sky is blue, and the grass is green. | Before leaving, ensure that you switch off the lights. | Similarity: 0.07
#
# The sky is blue, and the grass is green. | The boy was delighted with the gift he received. | Similarity: 0.03
#
# The sky is blue, and the grass is green. | Receiving the present made the young lad ecstatic. | Similarity: -0.02
#
# The sky is blue, and the grass is green. | She has a preference for Italian cuisine. | Similarity: -0.01
#
# The sky is blue, and the grass is green. | Her favorite type of food is from Italy. | Similarity: 0.04
#
# The sky is blue, and the grass is green. | The software engineer resolved the issue by modifying the code. | Similarity: 0.01
#
# The sky is blue, and the grass is green. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.00
#
# The sky is blue, and the grass is green. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.16
#
# The sky is blue, and the grass is green. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.17
#
# The sky is blue, and the grass is green. | The house was engulfed in a raging fire. | Similarity: 0.03
#
# The sky is blue, and the grass is green. | Flames rapidly consumed the residence. | Similarity: 0.08
#
# The sky is blue, and the grass is green. | He is constantly browsing the internet for the latest news. | Similarity: 0.08
#
# The sky is blue, and the grass is green. | He frequently scours the web to stay updated on current events. | Similarity: -0.04
#
# The sky is blue, and the grass is green. | The puppy was playing with a toy in the garden. | Similarity: 0.16
#
# The sky is blue, and the grass is green. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.19
#
# The sky is blue, and the grass is green. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.23
#
# The grass is green, and the sky is blue. | It's a sunny day today. | Similarity: 0.41
#
# The grass is green, and the sky is blue. | The weather is sunny today. | Similarity: 0.42
#
# The grass is green, and the sky is blue. | She was wearing a beautiful red dress. | Similarity: 0.06
#
# The grass is green, and the sky is blue. | She had on a gorgeous red dress. | Similarity: 0.07
#
# The grass is green, and the sky is blue. | I'm going to the supermarket to buy some groceries. | Similarity: 0.14
#
# The grass is green, and the sky is blue. | I'm heading to the supermarket to purchase some groceries. | Similarity: 0.17
#
# The grass is green, and the sky is blue. | He didn't like the movie because it was too long. | Similarity: 0.02
#
# The grass is green, and the sky is blue. | He disliked the movie as it was too lengthy. | Similarity: -0.01
#
# The grass is green, and the sky is blue. | The train was delayed due to technical issues. | Similarity: -0.03
#
# The grass is green, and the sky is blue. | Technical issues caused the train to be delayed. | Similarity: -0.01
#
# The grass is green, and the sky is blue. | I'll have a cup of coffee with milk and sugar, please. | Similarity: 0.11
#
# The grass is green, and the sky is blue. | Can I get a coffee with milk and sugar, please? | Similarity: 0.04
#
# The grass is green, and the sky is blue. | The conference was very informative and interesting. | Similarity: 0.03
#
# The grass is green, and the sky is blue. | The conference turned out to be interesting and informative. | Similarity: 0.04
#
# The grass is green, and the sky is blue. | He enjoys listening to classical music in his free time. | Similarity: 0.09
#
# The grass is green, and the sky is blue. | In his leisure time, he likes to listen to classical music. | Similarity: 0.12
#
# The grass is green, and the sky is blue. | Please make sure you turn off the lights before leaving. | Similarity: 0.12
#
# The grass is green, and the sky is blue. | Before leaving, ensure that you switch off the lights. | Similarity: 0.07
#
# The grass is green, and the sky is blue. | The boy was delighted with the gift he received. | Similarity: 0.04
#
# The grass is green, and the sky is blue. | Receiving the present made the young lad ecstatic. | Similarity: -0.02
#
# The grass is green, and the sky is blue. | She has a preference for Italian cuisine. | Similarity: -0.02
#
# The grass is green, and the sky is blue. | Her favorite type of food is from Italy. | Similarity: 0.03
#
# The grass is green, and the sky is blue. | The software engineer resolved the issue by modifying the code. | Similarity: 0.02
#
# The grass is green, and the sky is blue. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.01
#
# The grass is green, and the sky is blue. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.17
#
# The grass is green, and the sky is blue. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.18
#
# The grass is green, and the sky is blue. | The house was engulfed in a raging fire. | Similarity: 0.03
#
# The grass is green, and the sky is blue. | Flames rapidly consumed the residence. | Similarity: 0.08
#
# The grass is green, and the sky is blue. | He is constantly browsing the internet for the latest news. | Similarity: 0.08
#
# The grass is green, and the sky is blue. | He frequently scours the web to stay updated on current events. | Similarity: -0.03
#
# The grass is green, and the sky is blue. | The puppy was playing with a toy in the garden. | Similarity: 0.18
#
# The grass is green, and the sky is blue. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.20
#
# The grass is green, and the sky is blue. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.23
#
# It's a sunny day today. | The weather is sunny today. | Similarity: 0.89
#
# It's a sunny day today. | She was wearing a beautiful red dress. | Similarity: 0.11
#
# It's a sunny day today. | She had on a gorgeous red dress. | Similarity: 0.14
#
# It's a sunny day today. | I'm going to the supermarket to buy some groceries. | Similarity: 0.25
#
# It's a sunny day today. | I'm heading to the supermarket to purchase some groceries. | Similarity: 0.24
#
# It's a sunny day today. | He didn't like the movie because it was too long. | Similarity: -0.00
#
# It's a sunny day today. | He disliked the movie as it was too lengthy. | Similarity: -0.02
#
# It's a sunny day today. | The train was delayed due to technical issues. | Similarity: 0.01
#
# It's a sunny day today. | Technical issues caused the train to be delayed. | Similarity: 0.03
#
# It's a sunny day today. | I'll have a cup of coffee with milk and sugar, please. | Similarity: 0.23
#
# It's a sunny day today. | Can I get a coffee with milk and sugar, please? | Similarity: 0.12
#
# It's a sunny day today. | The conference was very informative and interesting. | Similarity: 0.05
#
# It's a sunny day today. | The conference turned out to be interesting and informative. | Similarity: 0.08
#
# It's a sunny day today. | He enjoys listening to classical music in his free time. | Similarity: 0.04
#
# It's a sunny day today. | In his leisure time, he likes to listen to classical music. | Similarity: 0.10
#
# It's a sunny day today. | Please make sure you turn off the lights before leaving. | Similarity: 0.20
#
# It's a sunny day today. | Before leaving, ensure that you switch off the lights. | Similarity: 0.10
#
# It's a sunny day today. | The boy was delighted with the gift he received. | Similarity: 0.02
#
# It's a sunny day today. | Receiving the present made the young lad ecstatic. | Similarity: 0.11
#
# It's a sunny day today. | She has a preference for Italian cuisine. | Similarity: 0.01
#
# It's a sunny day today. | Her favorite type of food is from Italy. | Similarity: 0.02
#
# It's a sunny day today. | The software engineer resolved the issue by modifying the code. | Similarity: 0.01
#
# It's a sunny day today. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.06
#
# It's a sunny day today. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.23
#
# It's a sunny day today. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.28
#
# It's a sunny day today. | The house was engulfed in a raging fire. | Similarity: 0.07
#
# It's a sunny day today. | Flames rapidly consumed the residence. | Similarity: 0.13
#
# It's a sunny day today. | He is constantly browsing the internet for the latest news. | Similarity: 0.18
#
# It's a sunny day today. | He frequently scours the web to stay updated on current events. | Similarity: 0.08
#
# It's a sunny day today. | The puppy was playing with a toy in the garden. | Similarity: 0.03
#
# It's a sunny day today. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.06
#
# It's a sunny day today. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.07
#
# The weather is sunny today. | She was wearing a beautiful red dress. | Similarity: 0.08
#
# The weather is sunny today. | She had on a gorgeous red dress. | Similarity: 0.09
#
# The weather is sunny today. | I'm going to the supermarket to buy some groceries. | Similarity: 0.13
#
# The weather is sunny today. | I'm heading to the supermarket to purchase some groceries. | Similarity: 0.16
#
# The weather is sunny today. | He didn't like the movie because it was too long. | Similarity: -0.06
#
# The weather is sunny today. | He disliked the movie as it was too lengthy. | Similarity: -0.08
#
# The weather is sunny today. | The train was delayed due to technical issues. | Similarity: -0.02
#
# The weather is sunny today. | Technical issues caused the train to be delayed. | Similarity: -0.01
#
# The weather is sunny today. | I'll have a cup of coffee with milk and sugar, please. | Similarity: 0.15
#
# The weather is sunny today. | Can I get a coffee with milk and sugar, please? | Similarity: 0.08
#
# The weather is sunny today. | The conference was very informative and interesting. | Similarity: -0.04
#
# The weather is sunny today. | The conference turned out to be interesting and informative. | Similarity: -0.02
#
# The weather is sunny today. | He enjoys listening to classical music in his free time. | Similarity: 0.05
#
# The weather is sunny today. | In his leisure time, he likes to listen to classical music. | Similarity: 0.12
#
# The weather is sunny today. | Please make sure you turn off the lights before leaving. | Similarity: 0.14
#
# The weather is sunny today. | Before leaving, ensure that you switch off the lights. | Similarity: 0.05
#
# The weather is sunny today. | The boy was delighted with the gift he received. | Similarity: -0.01
#
# The weather is sunny today. | Receiving the present made the young lad ecstatic. | Similarity: 0.02
#
# The weather is sunny today. | She has a preference for Italian cuisine. | Similarity: -0.01
#
# The weather is sunny today. | Her favorite type of food is from Italy. | Similarity: 0.01
#
# The weather is sunny today. | The software engineer resolved the issue by modifying the code. | Similarity: -0.01
#
# The weather is sunny today. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.02
#
# The weather is sunny today. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.21
#
# The weather is sunny today. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.29
#
# The weather is sunny today. | The house was engulfed in a raging fire. | Similarity: 0.04
#
# The weather is sunny today. | Flames rapidly consumed the residence. | Similarity: 0.10
#
# The weather is sunny today. | He is constantly browsing the internet for the latest news. | Similarity: 0.15
#
# The weather is sunny today. | He frequently scours the web to stay updated on current events. | Similarity: 0.02
#
# The weather is sunny today. | The puppy was playing with a toy in the garden. | Similarity: 0.05
#
# The weather is sunny today. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.08
#
# The weather is sunny today. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.11
#
# She was wearing a beautiful red dress. | She had on a gorgeous red dress. | Similarity: 0.94
#
# She was wearing a beautiful red dress. | I'm going to the supermarket to buy some groceries. | Similarity: 0.10
#
# She was wearing a beautiful red dress. | I'm heading to the supermarket to purchase some groceries. | Similarity: 0.09
#
# She was wearing a beautiful red dress. | He didn't like the movie because it was too long. | Similarity: 0.02
#
# She was wearing a beautiful red dress. | He disliked the movie as it was too lengthy. | Similarity: 0.03
#
# She was wearing a beautiful red dress. | The train was delayed due to technical issues. | Similarity: 0.04
#
# She was wearing a beautiful red dress. | Technical issues caused the train to be delayed. | Similarity: 0.03
#
# She was wearing a beautiful red dress. | I'll have a cup of coffee with milk and sugar, please. | Similarity: 0.06
#
# She was wearing a beautiful red dress. | Can I get a coffee with milk and sugar, please? | Similarity: 0.02
#
# She was wearing a beautiful red dress. | The conference was very informative and interesting. | Similarity: 0.08
#
# She was wearing a beautiful red dress. | The conference turned out to be interesting and informative. | Similarity: 0.05
#
# She was wearing a beautiful red dress. | He enjoys listening to classical music in his free time. | Similarity: -0.00
#
# She was wearing a beautiful red dress. | In his leisure time, he likes to listen to classical music. | Similarity: 0.01
#
# She was wearing a beautiful red dress. | Please make sure you turn off the lights before leaving. | Similarity: 0.03
#
# She was wearing a beautiful red dress. | Before leaving, ensure that you switch off the lights. | Similarity: 0.02
#
# She was wearing a beautiful red dress. | The boy was delighted with the gift he received. | Similarity: 0.10
#
# She was wearing a beautiful red dress. | Receiving the present made the young lad ecstatic. | Similarity: 0.03
#
# She was wearing a beautiful red dress. | She has a preference for Italian cuisine. | Similarity: 0.20
#
# She was wearing a beautiful red dress. | Her favorite type of food is from Italy. | Similarity: 0.23
#
# She was wearing a beautiful red dress. | The software engineer resolved the issue by modifying the code. | Similarity: -0.01
#
# She was wearing a beautiful red dress. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.01
#
# She was wearing a beautiful red dress. | Due to the inclement weather, the baseball game was postponed. | Similarity: -0.00
#
# She was wearing a beautiful red dress. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.04
#
# She was wearing a beautiful red dress. | The house was engulfed in a raging fire. | Similarity: 0.10
#
# She was wearing a beautiful red dress. | Flames rapidly consumed the residence. | Similarity: 0.11
#
# She was wearing a beautiful red dress. | He is constantly browsing the internet for the latest news. | Similarity: -0.01
#
# She was wearing a beautiful red dress. | He frequently scours the web to stay updated on current events. | Similarity: -0.02
#
# She was wearing a beautiful red dress. | The puppy was playing with a toy in the garden. | Similarity: 0.03
#
# She was wearing a beautiful red dress. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.07
#
# She was wearing a beautiful red dress. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.08
#
# She had on a gorgeous red dress. | I'm going to the supermarket to buy some groceries. | Similarity: 0.10
#
# She had on a gorgeous red dress. | I'm heading to the supermarket to purchase some groceries. | Similarity: 0.10
#
# She had on a gorgeous red dress. | He didn't like the movie because it was too long. | Similarity: 0.04
#
# She had on a gorgeous red dress. | He disliked the movie as it was too lengthy. | Similarity: 0.03
#
# She had on a gorgeous red dress. | The train was delayed due to technical issues. | Similarity: 0.05
#
# She had on a gorgeous red dress. | Technical issues caused the train to be delayed. | Similarity: 0.04
#
# She had on a gorgeous red dress. | I'll have a cup of coffee with milk and sugar, please. | Similarity: 0.07
#
# She had on a gorgeous red dress. | Can I get a coffee with milk and sugar, please? | Similarity: 0.02
#
# She had on a gorgeous red dress. | The conference was very informative and interesting. | Similarity: 0.11
#
# She had on a gorgeous red dress. | The conference turned out to be interesting and informative. | Similarity: 0.09
#
# She had on a gorgeous red dress. | He enjoys listening to classical music in his free time. | Similarity: -0.02
#
# She had on a gorgeous red dress. | In his leisure time, he likes to listen to classical music. | Similarity: -0.00
#
# She had on a gorgeous red dress. | Please make sure you turn off the lights before leaving. | Similarity: 0.04
#
# She had on a gorgeous red dress. | Before leaving, ensure that you switch off the lights. | Similarity: 0.03
#
# She had on a gorgeous red dress. | The boy was delighted with the gift he received. | Similarity: 0.11
#
# She had on a gorgeous red dress. | Receiving the present made the young lad ecstatic. | Similarity: 0.05
#
# She had on a gorgeous red dress. | She has a preference for Italian cuisine. | Similarity: 0.24
#
# She had on a gorgeous red dress. | Her favorite type of food is from Italy. | Similarity: 0.26
#
# She had on a gorgeous red dress. | The software engineer resolved the issue by modifying the code. | Similarity: 0.03
#
# She had on a gorgeous red dress. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.03
#
# She had on a gorgeous red dress. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.04
#
# She had on a gorgeous red dress. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.08
#
# She had on a gorgeous red dress. | The house was engulfed in a raging fire. | Similarity: 0.10
#
# She had on a gorgeous red dress. | Flames rapidly consumed the residence. | Similarity: 0.14
#
# She had on a gorgeous red dress. | He is constantly browsing the internet for the latest news. | Similarity: -0.03
#
# She had on a gorgeous red dress. | He frequently scours the web to stay updated on current events. | Similarity: -0.01
#
# She had on a gorgeous red dress. | The puppy was playing with a toy in the garden. | Similarity: 0.05
#
# She had on a gorgeous red dress. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.09
#
# She had on a gorgeous red dress. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.10
#
# I'm going to the supermarket to buy some groceries. | I'm heading to the supermarket to purchase some groceries. | Similarity: 0.94
#
# I'm going to the supermarket to buy some groceries. | He didn't like the movie because it was too long. | Similarity: -0.04
#
# I'm going to the supermarket to buy some groceries. | He disliked the movie as it was too lengthy. | Similarity: -0.04
#
# I'm going to the supermarket to buy some groceries. | The train was delayed due to technical issues. | Similarity: -0.02
#
# I'm going to the supermarket to buy some groceries. | Technical issues caused the train to be delayed. | Similarity: 0.02
#
# I'm going to the supermarket to buy some groceries. | I'll have a cup of coffee with milk and sugar, please. | Similarity: 0.41
#
# I'm going to the supermarket to buy some groceries. | Can I get a coffee with milk and sugar, please? | Similarity: 0.29
#
# I'm going to the supermarket to buy some groceries. | The conference was very informative and interesting. | Similarity: 0.01
#
# I'm going to the supermarket to buy some groceries. | The conference turned out to be interesting and informative. | Similarity: 0.06
#
# I'm going to the supermarket to buy some groceries. | He enjoys listening to classical music in his free time. | Similarity: 0.05
#
# I'm going to the supermarket to buy some groceries. | In his leisure time, he likes to listen to classical music. | Similarity: 0.08
#
# I'm going to the supermarket to buy some groceries. | Please make sure you turn off the lights before leaving. | Similarity: 0.21
#
# I'm going to the supermarket to buy some groceries. | Before leaving, ensure that you switch off the lights. | Similarity: 0.17
#
# I'm going to the supermarket to buy some groceries. | The boy was delighted with the gift he received. | Similarity: 0.07
#
# I'm going to the supermarket to buy some groceries. | Receiving the present made the young lad ecstatic. | Similarity: 0.13
#
# I'm going to the supermarket to buy some groceries. | She has a preference for Italian cuisine. | Similarity: 0.15
#
# I'm going to the supermarket to buy some groceries. | Her favorite type of food is from Italy. | Similarity: 0.20
#
# I'm going to the supermarket to buy some groceries. | The software engineer resolved the issue by modifying the code. | Similarity: -0.10
#
# I'm going to the supermarket to buy some groceries. | By altering the programming, the tech expert fixed the problem. | Similarity: -0.12
#
# I'm going to the supermarket to buy some groceries. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.05
#
# I'm going to the supermarket to buy some groceries. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.05
#
# I'm going to the supermarket to buy some groceries. | The house was engulfed in a raging fire. | Similarity: -0.03
#
# I'm going to the supermarket to buy some groceries. | Flames rapidly consumed the residence. | Similarity: 0.06
#
# I'm going to the supermarket to buy some groceries. | He is constantly browsing the internet for the latest news. | Similarity: 0.11
#
# I'm going to the supermarket to buy some groceries. | He frequently scours the web to stay updated on current events. | Similarity: 0.03
#
# I'm going to the supermarket to buy some groceries. | The puppy was playing with a toy in the garden. | Similarity: 0.03
#
# I'm going to the supermarket to buy some groceries. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.02
#
# I'm going to the supermarket to buy some groceries. | The artist painted a beautiful landscape on the canvas. | Similarity: -0.12
#
# I'm heading to the supermarket to purchase some groceries. | He didn't like the movie because it was too long. | Similarity: -0.06
#
# I'm heading to the supermarket to purchase some groceries. | He disliked the movie as it was too lengthy. | Similarity: -0.06
#
# I'm heading to the supermarket to purchase some groceries. | The train was delayed due to technical issues. | Similarity: 0.01
#
# I'm heading to the supermarket to purchase some groceries. | Technical issues caused the train to be delayed. | Similarity: 0.04
#
# I'm heading to the supermarket to purchase some groceries. | I'll have a cup of coffee with milk and sugar, please. | Similarity: 0.43
#
# I'm heading to the supermarket to purchase some groceries. | Can I get a coffee with milk and sugar, please? | Similarity: 0.33
#
# I'm heading to the supermarket to purchase some groceries. | The conference was very informative and interesting. | Similarity: -0.00
#
# I'm heading to the supermarket to purchase some groceries. | The conference turned out to be interesting and informative. | Similarity: 0.04
#
# I'm heading to the supermarket to purchase some groceries. | He enjoys listening to classical music in his free time. | Similarity: 0.05
#
# I'm heading to the supermarket to purchase some groceries. | In his leisure time, he likes to listen to classical music. | Similarity: 0.08
#
# I'm heading to the supermarket to purchase some groceries. | Please make sure you turn off the lights before leaving. | Similarity: 0.20
#
# I'm heading to the supermarket to purchase some groceries. | Before leaving, ensure that you switch off the lights. | Similarity: 0.17
#
# I'm heading to the supermarket to purchase some groceries. | The boy was delighted with the gift he received. | Similarity: 0.09
#
# I'm heading to the supermarket to purchase some groceries. | Receiving the present made the young lad ecstatic. | Similarity: 0.11
#
# I'm heading to the supermarket to purchase some groceries. | She has a preference for Italian cuisine. | Similarity: 0.16
#
# I'm heading to the supermarket to purchase some groceries. | Her favorite type of food is from Italy. | Similarity: 0.21
#
# I'm heading to the supermarket to purchase some groceries. | The software engineer resolved the issue by modifying the code. | Similarity: -0.11
#
# I'm heading to the supermarket to purchase some groceries. | By altering the programming, the tech expert fixed the problem. | Similarity: -0.14
#
# I'm heading to the supermarket to purchase some groceries. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.04
#
# I'm heading to the supermarket to purchase some groceries. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.02
#
# I'm heading to the supermarket to purchase some groceries. | The house was engulfed in a raging fire. | Similarity: -0.05
#
# I'm heading to the supermarket to purchase some groceries. | Flames rapidly consumed the residence. | Similarity: 0.04
#
# I'm heading to the supermarket to purchase some groceries. | He is constantly browsing the internet for the latest news. | Similarity: 0.09
#
# I'm heading to the supermarket to purchase some groceries. | He frequently scours the web to stay updated on current events. | Similarity: 0.02
#
# I'm heading to the supermarket to purchase some groceries. | The puppy was playing with a toy in the garden. | Similarity: 0.04
#
# I'm heading to the supermarket to purchase some groceries. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.03
#
# I'm heading to the supermarket to purchase some groceries. | The artist painted a beautiful landscape on the canvas. | Similarity: -0.10
#
# He didn't like the movie because it was too long. | He disliked the movie as it was too lengthy. | Similarity: 0.90
#
# He didn't like the movie because it was too long. | The train was delayed due to technical issues. | Similarity: 0.18
#
# He didn't like the movie because it was too long. | Technical issues caused the train to be delayed. | Similarity: 0.19
#
# He didn't like the movie because it was too long. | I'll have a cup of coffee with milk and sugar, please. | Similarity: -0.05
#
# He didn't like the movie because it was too long. | Can I get a coffee with milk and sugar, please? | Similarity: -0.04
#
# He didn't like the movie because it was too long. | The conference was very informative and interesting. | Similarity: 0.04
#
# He didn't like the movie because it was too long. | The conference turned out to be interesting and informative. | Similarity: 0.01
#
# He didn't like the movie because it was too long. | He enjoys listening to classical music in his free time. | Similarity: 0.26
#
# He didn't like the movie because it was too long. | In his leisure time, he likes to listen to classical music. | Similarity: 0.24
#
# He didn't like the movie because it was too long. | Please make sure you turn off the lights before leaving. | Similarity: 0.01
#
# He didn't like the movie because it was too long. | Before leaving, ensure that you switch off the lights. | Similarity: 0.01
#
# He didn't like the movie because it was too long. | The boy was delighted with the gift he received. | Similarity: 0.15
#
# He didn't like the movie because it was too long. | Receiving the present made the young lad ecstatic. | Similarity: 0.18
#
# He didn't like the movie because it was too long. | She has a preference for Italian cuisine. | Similarity: 0.12
#
# He didn't like the movie because it was too long. | Her favorite type of food is from Italy. | Similarity: 0.06
#
# He didn't like the movie because it was too long. | The software engineer resolved the issue by modifying the code. | Similarity: 0.07
#
# He didn't like the movie because it was too long. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.05
#
# He didn't like the movie because it was too long. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.09
#
# He didn't like the movie because it was too long. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.09
#
# He didn't like the movie because it was too long. | The house was engulfed in a raging fire. | Similarity: 0.13
#
# He didn't like the movie because it was too long. | Flames rapidly consumed the residence. | Similarity: 0.10
#
# He didn't like the movie because it was too long. | He is constantly browsing the internet for the latest news. | Similarity: 0.16
#
# He didn't like the movie because it was too long. | He frequently scours the web to stay updated on current events. | Similarity: 0.10
#
# He didn't like the movie because it was too long. | The puppy was playing with a toy in the garden. | Similarity: 0.04
#
# He didn't like the movie because it was too long. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.09
#
# He didn't like the movie because it was too long. | The artist painted a beautiful landscape on the canvas. | Similarity: -0.00
#
# He disliked the movie as it was too lengthy. | The train was delayed due to technical issues. | Similarity: 0.13
#
# He disliked the movie as it was too lengthy. | Technical issues caused the train to be delayed. | Similarity: 0.13
#
# He disliked the movie as it was too lengthy. | I'll have a cup of coffee with milk and sugar, please. | Similarity: -0.07
#
# He disliked the movie as it was too lengthy. | Can I get a coffee with milk and sugar, please? | Similarity: -0.04
#
# He disliked the movie as it was too lengthy. | The conference was very informative and interesting. | Similarity: 0.10
#
# He disliked the movie as it was too lengthy. | The conference turned out to be interesting and informative. | Similarity: 0.05
#
# He disliked the movie as it was too lengthy. | He enjoys listening to classical music in his free time. | Similarity: 0.24
#
# He disliked the movie as it was too lengthy. | In his leisure time, he likes to listen to classical music. | Similarity: 0.24
#
# He disliked the movie as it was too lengthy. | Please make sure you turn off the lights before leaving. | Similarity: -0.00
#
# He disliked the movie as it was too lengthy. | Before leaving, ensure that you switch off the lights. | Similarity: 0.02
#
# He disliked the movie as it was too lengthy. | The boy was delighted with the gift he received. | Similarity: 0.13
#
# He disliked the movie as it was too lengthy. | Receiving the present made the young lad ecstatic. | Similarity: 0.17
#
# He disliked the movie as it was too lengthy. | She has a preference for Italian cuisine. | Similarity: 0.11
#
# He disliked the movie as it was too lengthy. | Her favorite type of food is from Italy. | Similarity: 0.05
#
# He disliked the movie as it was too lengthy. | The software engineer resolved the issue by modifying the code. | Similarity: 0.05
#
# He disliked the movie as it was too lengthy. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.07
#
# He disliked the movie as it was too lengthy. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.06
#
# He disliked the movie as it was too lengthy. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.06
#
# He disliked the movie as it was too lengthy. | The house was engulfed in a raging fire. | Similarity: 0.11
#
# He disliked the movie as it was too lengthy. | Flames rapidly consumed the residence. | Similarity: 0.10
#
# He disliked the movie as it was too lengthy. | He is constantly browsing the internet for the latest news. | Similarity: 0.15
#
# He disliked the movie as it was too lengthy. | He frequently scours the web to stay updated on current events. | Similarity: 0.12
#
# He disliked the movie as it was too lengthy. | The puppy was playing with a toy in the garden. | Similarity: 0.06
#
# He disliked the movie as it was too lengthy. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.06
#
# He disliked the movie as it was too lengthy. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.02
#
# The train was delayed due to technical issues. | Technical issues caused the train to be delayed. | Similarity: 0.97
#
# The train was delayed due to technical issues. | I'll have a cup of coffee with milk and sugar, please. | Similarity: -0.03
#
# The train was delayed due to technical issues. | Can I get a coffee with milk and sugar, please? | Similarity: -0.00
#
# The train was delayed due to technical issues. | The conference was very informative and interesting. | Similarity: 0.07
#
# The train was delayed due to technical issues. | The conference turned out to be interesting and informative. | Similarity: 0.05
#
# The train was delayed due to technical issues. | He enjoys listening to classical music in his free time. | Similarity: 0.05
#
# The train was delayed due to technical issues. | In his leisure time, he likes to listen to classical music. | Similarity: 0.02
#
# The train was delayed due to technical issues. | Please make sure you turn off the lights before leaving. | Similarity: 0.02
#
# The train was delayed due to technical issues. | Before leaving, ensure that you switch off the lights. | Similarity: 0.05
#
# The train was delayed due to technical issues. | The boy was delighted with the gift he received. | Similarity: 0.01
#
# The train was delayed due to technical issues. | Receiving the present made the young lad ecstatic. | Similarity: 0.07
#
# The train was delayed due to technical issues. | She has a preference for Italian cuisine. | Similarity: -0.03
#
# The train was delayed due to technical issues. | Her favorite type of food is from Italy. | Similarity: -0.02
#
# The train was delayed due to technical issues. | The software engineer resolved the issue by modifying the code. | Similarity: 0.19
#
# The train was delayed due to technical issues. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.37
#
# The train was delayed due to technical issues. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.42
#
# The train was delayed due to technical issues. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.28
#
# The train was delayed due to technical issues. | The house was engulfed in a raging fire. | Similarity: -0.05
#
# The train was delayed due to technical issues. | Flames rapidly consumed the residence. | Similarity: -0.02
#
# The train was delayed due to technical issues. | He is constantly browsing the internet for the latest news. | Similarity: -0.00
#
# The train was delayed due to technical issues. | He frequently scours the web to stay updated on current events. | Similarity: 0.05
#
# The train was delayed due to technical issues. | The puppy was playing with a toy in the garden. | Similarity: 0.02
#
# The train was delayed due to technical issues. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.01
#
# The train was delayed due to technical issues. | The artist painted a beautiful landscape on the canvas. | Similarity: -0.14
#
# Technical issues caused the train to be delayed. | I'll have a cup of coffee with milk and sugar, please. | Similarity: 0.00
#
# Technical issues caused the train to be delayed. | Can I get a coffee with milk and sugar, please? | Similarity: 0.01
#
# Technical issues caused the train to be delayed. | The conference was very informative and interesting. | Similarity: 0.09
#
# Technical issues caused the train to be delayed. | The conference turned out to be interesting and informative. | Similarity: 0.09
#
# Technical issues caused the train to be delayed. | He enjoys listening to classical music in his free time. | Similarity: 0.07
#
# Technical issues caused the train to be delayed. | In his leisure time, he likes to listen to classical music. | Similarity: 0.03
#
# Technical issues caused the train to be delayed. | Please make sure you turn off the lights before leaving. | Similarity: 0.06
#
# Technical issues caused the train to be delayed. | Before leaving, ensure that you switch off the lights. | Similarity: 0.10
#
# Technical issues caused the train to be delayed. | The boy was delighted with the gift he received. | Similarity: 0.02
#
# Technical issues caused the train to be delayed. | Receiving the present made the young lad ecstatic. | Similarity: 0.10
#
# Technical issues caused the train to be delayed. | She has a preference for Italian cuisine. | Similarity: -0.01
#
# Technical issues caused the train to be delayed. | Her favorite type of food is from Italy. | Similarity: -0.01
#
# Technical issues caused the train to be delayed. | The software engineer resolved the issue by modifying the code. | Similarity: 0.20
#
# Technical issues caused the train to be delayed. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.36
#
# Technical issues caused the train to be delayed. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.43
#
# Technical issues caused the train to be delayed. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.30
#
# Technical issues caused the train to be delayed. | The house was engulfed in a raging fire. | Similarity: -0.03
#
# Technical issues caused the train to be delayed. | Flames rapidly consumed the residence. | Similarity: 0.02
#
# Technical issues caused the train to be delayed. | He is constantly browsing the internet for the latest news. | Similarity: 0.04
#
# Technical issues caused the train to be delayed. | He frequently scours the web to stay updated on current events. | Similarity: 0.09
#
# ...
#
# Please make sure you turn off the lights before leaving. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.00
#
# Please make sure you turn off the lights before leaving. | The artist painted a beautiful landscape on the canvas. | Similarity: -0.04
#
# Before leaving, ensure that you switch off the lights. | The boy was delighted with the gift he received. | Similarity: -0.01
#
# Before leaving, ensure that you switch off the lights. | Receiving the present made the young lad ecstatic. | Similarity: 0.02
#
# Before leaving, ensure that you switch off the lights. | She has a preference for Italian cuisine. | Similarity: 0.00
#
# Before leaving, ensure that you switch off the lights. | Her favorite type of food is from Italy. | Similarity: -0.03
#
# Before leaving, ensure that you switch off the lights. | The software engineer resolved the issue by modifying the code. | Similarity: 0.18
#
# Before leaving, ensure that you switch off the lights. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.13
#
# Before leaving, ensure that you switch off the lights. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.17
#
# Before leaving, ensure that you switch off the lights. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.13
#
# Before leaving, ensure that you switch off the lights. | The house was engulfed in a raging fire. | Similarity: 0.09
#
# Before leaving, ensure that you switch off the lights. | Flames rapidly consumed the residence. | Similarity: 0.26
#
# Before leaving, ensure that you switch off the lights. | He is constantly browsing the internet for the latest news. | Similarity: 0.15
#
# Before leaving, ensure that you switch off the lights. | He frequently scours the web to stay updated on current events. | Similarity: 0.10
#
# Before leaving, ensure that you switch off the lights. | The puppy was playing with a toy in the garden. | Similarity: -0.06
#
# Before leaving, ensure that you switch off the lights. | In the yard, the young dog was frolicking with its plaything. | Similarity: -0.01
#
# Before leaving, ensure that you switch off the lights. | The artist painted a beautiful landscape on the canvas. | Similarity: -0.06
#
# The boy was delighted with the gift he received. | Receiving the present made the young lad ecstatic. | Similarity: 0.53
#
# The boy was delighted with the gift he received. | She has a preference for Italian cuisine. | Similarity: 0.08
#
# The boy was delighted with the gift he received. | Her favorite type of food is from Italy. | Similarity: 0.11
#
# The boy was delighted with the gift he received. | The software engineer resolved the issue by modifying the code. | Similarity: 0.01
#
# The boy was delighted with the gift he received. | By altering the programming, the tech expert fixed the problem. | Similarity: -0.02
#
# The boy was delighted with the gift he received. | Due to the inclement weather, the baseball game was postponed. | Similarity: -0.05
#
# The boy was delighted with the gift he received. | The baseball match was rescheduled because of bad weather conditions. | Similarity: -0.11
#
# The boy was delighted with the gift he received. | The house was engulfed in a raging fire. | Similarity: 0.06
#
# The boy was delighted with the gift he received. | Flames rapidly consumed the residence. | Similarity: 0.04
#
# The boy was delighted with the gift he received. | He is constantly browsing the internet for the latest news. | Similarity: 0.14
#
# The boy was delighted with the gift he received. | He frequently scours the web to stay updated on current events. | Similarity: 0.10
#
# The boy was delighted with the gift he received. | The puppy was playing with a toy in the garden. | Similarity: 0.19
#
# The boy was delighted with the gift he received. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.20
#
# The boy was delighted with the gift he received. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.12
#
# Receiving the present made the young lad ecstatic. | She has a preference for Italian cuisine. | Similarity: 0.03
#
# Receiving the present made the young lad ecstatic. | Her favorite type of food is from Italy. | Similarity: -0.01
#
# Receiving the present made the young lad ecstatic. | The software engineer resolved the issue by modifying the code. | Similarity: 0.01
#
# Receiving the present made the young lad ecstatic. | By altering the programming, the tech expert fixed the problem. | Similarity: -0.07
#
# Receiving the present made the young lad ecstatic. | Due to the inclement weather, the baseball game was postponed. | Similarity: -0.08
#
# Receiving the present made the young lad ecstatic. | The baseball match was rescheduled because of bad weather conditions. | Similarity: -0.11
#
# Receiving the present made the young lad ecstatic. | The house was engulfed in a raging fire. | Similarity: 0.03
#
# Receiving the present made the young lad ecstatic. | Flames rapidly consumed the residence. | Similarity: 0.07
#
# Receiving the present made the young lad ecstatic. | He is constantly browsing the internet for the latest news. | Similarity: 0.24
#
# Receiving the present made the young lad ecstatic. | He frequently scours the web to stay updated on current events. | Similarity: 0.20
#
# Receiving the present made the young lad ecstatic. | The puppy was playing with a toy in the garden. | Similarity: 0.07
#
# Receiving the present made the young lad ecstatic. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.16
#
# Receiving the present made the young lad ecstatic. | The artist painted a beautiful landscape on the canvas. | Similarity: -0.01
#
# She has a preference for Italian cuisine. | Her favorite type of food is from Italy. | Similarity: 0.85
#
# She has a preference for Italian cuisine. | The software engineer resolved the issue by modifying the code. | Similarity: 0.04
#
# She has a preference for Italian cuisine. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.00
#
# She has a preference for Italian cuisine. | Due to the inclement weather, the baseball game was postponed. | Similarity: -0.06
#
# She has a preference for Italian cuisine. | The baseball match was rescheduled because of bad weather conditions. | Similarity: -0.05
#
# She has a preference for Italian cuisine. | The house was engulfed in a raging fire. | Similarity: -0.02
#
# She has a preference for Italian cuisine. | Flames rapidly consumed the residence. | Similarity: 0.10
#
# She has a preference for Italian cuisine. | He is constantly browsing the internet for the latest news. | Similarity: 0.09
#
# She has a preference for Italian cuisine. | He frequently scours the web to stay updated on current events. | Similarity: 0.02
#
# She has a preference for Italian cuisine. | The puppy was playing with a toy in the garden. | Similarity: -0.00
#
# She has a preference for Italian cuisine. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.05
#
# She has a preference for Italian cuisine. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.05
#
# Her favorite type of food is from Italy. | The software engineer resolved the issue by modifying the code. | Similarity: 0.05
#
# Her favorite type of food is from Italy. | By altering the programming, the tech expert fixed the problem. | Similarity: -0.03
#
# Her favorite type of food is from Italy. | Due to the inclement weather, the baseball game was postponed. | Similarity: -0.03
#
# Her favorite type of food is from Italy. | The baseball match was rescheduled because of bad weather conditions. | Similarity: -0.03
#
# Her favorite type of food is from Italy. | The house was engulfed in a raging fire. | Similarity: -0.01
#
# Her favorite type of food is from Italy. | Flames rapidly consumed the residence. | Similarity: 0.10
#
# Her favorite type of food is from Italy. | He is constantly browsing the internet for the latest news. | Similarity: 0.10
#
# Her favorite type of food is from Italy. | He frequently scours the web to stay updated on current events. | Similarity: 0.03
#
# Her favorite type of food is from Italy. | The puppy was playing with a toy in the garden. | Similarity: 0.04
#
# Her favorite type of food is from Italy. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.09
#
# Her favorite type of food is from Italy. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.05
#
# The software engineer resolved the issue by modifying the code. | By altering the programming, the tech expert fixed the problem. | Similarity: 0.55
#
# The software engineer resolved the issue by modifying the code. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.20
#
# The software engineer resolved the issue by modifying the code. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.13
#
# The software engineer resolved the issue by modifying the code. | The house was engulfed in a raging fire. | Similarity: -0.03
#
# The software engineer resolved the issue by modifying the code. | Flames rapidly consumed the residence. | Similarity: 0.03
#
# The software engineer resolved the issue by modifying the code. | He is constantly browsing the internet for the latest news. | Similarity: 0.06
#
# The software engineer resolved the issue by modifying the code. | He frequently scours the web to stay updated on current events. | Similarity: 0.06
#
# The software engineer resolved the issue by modifying the code. | The puppy was playing with a toy in the garden. | Similarity: -0.02
#
# The software engineer resolved the issue by modifying the code. | In the yard, the young dog was frolicking with its plaything. | Similarity: -0.01
#
# The software engineer resolved the issue by modifying the code. | The artist painted a beautiful landscape on the canvas. | Similarity: -0.02
#
# By altering the programming, the tech expert fixed the problem. | Due to the inclement weather, the baseball game was postponed. | Similarity: 0.21
#
# By altering the programming, the tech expert fixed the problem. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.12
#
# By altering the programming, the tech expert fixed the problem. | The house was engulfed in a raging fire. | Similarity: -0.04
#
# By altering the programming, the tech expert fixed the problem. | Flames rapidly consumed the residence. | Similarity: -0.01
#
# By altering the programming, the tech expert fixed the problem. | He is constantly browsing the internet for the latest news. | Similarity: 0.06
#
# By altering the programming, the tech expert fixed the problem. | He frequently scours the web to stay updated on current events. | Similarity: 0.07
#
# By altering the programming, the tech expert fixed the problem. | The puppy was playing with a toy in the garden. | Similarity: 0.03
#
# By altering the programming, the tech expert fixed the problem. | In the yard, the young dog was frolicking with its plaything. | Similarity: -0.01
#
# By altering the programming, the tech expert fixed the problem. | The artist painted a beautiful landscape on the canvas. | Similarity: -0.01
#
# Due to the inclement weather, the baseball game was postponed. | The baseball match was rescheduled because of bad weather conditions. | Similarity: 0.76
#
# Due to the inclement weather, the baseball game was postponed. | The house was engulfed in a raging fire. | Similarity: 0.11
#
# Due to the inclement weather, the baseball game was postponed. | Flames rapidly consumed the residence. | Similarity: 0.11
#
# Due to the inclement weather, the baseball game was postponed. | He is constantly browsing the internet for the latest news. | Similarity: 0.02
#
# Due to the inclement weather, the baseball game was postponed. | He frequently scours the web to stay updated on current events. | Similarity: 0.06
#
# Due to the inclement weather, the baseball game was postponed. | The puppy was playing with a toy in the garden. | Similarity: 0.10
#
# Due to the inclement weather, the baseball game was postponed. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.08
#
# Due to the inclement weather, the baseball game was postponed. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.01
#
# The baseball match was rescheduled because of bad weather conditions. | The house was engulfed in a raging fire. | Similarity: 0.10
#
# The baseball match was rescheduled because of bad weather conditions. | Flames rapidly consumed the residence. | Similarity: 0.14
#
# The baseball match was rescheduled because of bad weather conditions. | He is constantly browsing the internet for the latest news. | Similarity: 0.03
#
# The baseball match was rescheduled because of bad weather conditions. | He frequently scours the web to stay updated on current events. | Similarity: 0.13
#
# The baseball match was rescheduled because of bad weather conditions. | The puppy was playing with a toy in the garden. | Similarity: 0.01
#
# The baseball match was rescheduled because of bad weather conditions. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.08
#
# The baseball match was rescheduled because of bad weather conditions. | The artist painted a beautiful landscape on the canvas. | Similarity: -0.05
#
# The house was engulfed in a raging fire. | Flames rapidly consumed the residence. | Similarity: 0.64
#
# The house was engulfed in a raging fire. | He is constantly browsing the internet for the latest news. | Similarity: 0.04
#
# The house was engulfed in a raging fire. | He frequently scours the web to stay updated on current events. | Similarity: -0.03
#
# The house was engulfed in a raging fire. | The puppy was playing with a toy in the garden. | Similarity: 0.10
#
# The house was engulfed in a raging fire. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.15
#
# The house was engulfed in a raging fire. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.08
#
# Flames rapidly consumed the residence. | He is constantly browsing the internet for the latest news. | Similarity: 0.07
#
# Flames rapidly consumed the residence. | He frequently scours the web to stay updated on current events. | Similarity: 0.07
#
# Flames rapidly consumed the residence. | The puppy was playing with a toy in the garden. | Similarity: -0.02
#
# Flames rapidly consumed the residence. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.11
#
# Flames rapidly consumed the residence. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.11
#
# He is constantly browsing the internet for the latest news. | He frequently scours the web to stay updated on current events. | Similarity: 0.64
#
# He is constantly browsing the internet for the latest news. | The puppy was playing with a toy in the garden. | Similarity: 0.04
#
# He is constantly browsing the internet for the latest news. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.08
#
# He is constantly browsing the internet for the latest news. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.06
#
# He frequently scours the web to stay updated on current events. | The puppy was playing with a toy in the garden. | Similarity: -0.02
#
# He frequently scours the web to stay updated on current events. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.03
#
# He frequently scours the web to stay updated on current events. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.01
#
# The puppy was playing with a toy in the garden. | In the yard, the young dog was frolicking with its plaything. | Similarity: 0.62
#
# The puppy was playing with a toy in the garden. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.15
#
# In the yard, the young dog was frolicking with its plaything. | The artist painted a beautiful landscape on the canvas. | Similarity: 0.13

# %% [markdown]
# # Document Clustering
#
# K-means clustering is a popular unsupervised machine learning algorithm that groups data points into k clusters based on their similarity. In our case, we want to group documents based on their semantic similarity. The algorithm requires us to specify the number of clusters k in advance.

# %%
corpus = [
    "The apple is a sweet fruit",
    "Oranges are citrus fruits",
    "Bananas are rich in potassium",
    "Strawberries are red fruits",
    "Dogs are domesticated animals",
    "Cats are also pets",
    "Elephants are the largest land mammals",
    "Cows provide us with milk",
    "Sharks are marine predators",
    "Whales are the largest marine mammals",
    "Dolphins are very intelligent",
    "Artificial intelligence is the future",
    "Machine learning is a subset of AI",
    "Deep learning is a part of machine learning",
    "Neural networks are used in deep learning",
]

df = pd.DataFrame({'documents': corpus})

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# Encode the documents in the corpus
document_embeddings = model.encode(corpus)

# %%
from sklearn.cluster import KMeans
num_clusters = 3
clustering_model = KMeans(n_clusters=num_clusters, init='k-means++', max_iter=300, n_init=10)
clustering_model.fit(document_embeddings)
cluster_assignment = clustering_model.labels_

df['cluster'] = cluster_assignment

# %%
for i in range(num_clusters):
    print(f"Cluster {i}:")
    print(df[df['cluster'] == i]['documents'].values, "\n")
# Out:
# Cluster 0:
# ['The apple is a sweet fruit' 'Oranges are citrus fruits'
#  'Bananas are rich in potassium' 'Strawberries are red fruits']
#
# Cluster 1:
# ['Dogs are domesticated animals' 'Cats are also pets'
#  'Elephants are the largest land mammals' 'Cows provide us with milk'
#  'Sharks are marine predators' 'Whales are the largest marine mammals'
#  'Dolphins are very intelligent']
#
# Cluster 2:
# ['Artificial intelligence is the future'
#  'Machine learning is a subset of AI'
#  'Deep learning is a part of machine learning'
#  'Neural networks are used in deep learning']

# %% [markdown]
# # Community Detection with Sentence Transformers
#
# The sentence_transformers library provides a utility for community detection which applies a threshold on the cosine similarity score to identify distinct communities of sentences that are semantically similar. This method can be particularly helpful for organizing a large corpus of text into meaningful groups.
#
#
#
#
# The [`community_detection`](https://www.sbert.net/docs/package_reference/util.html#sentence_transformers.util.community_detection) function in the Sentence Transformers library is a useful utility for finding clusters or communities of semantically similar sentences. Here are the details of the function parameters:
#
# - `document_embeddings`: This is the list of embeddings for the documents in your corpus. The embeddings can be created using any of the Sentence Transformer models. The embeddings should be in the form of a 2D tensor or a list of 1D tensors. Each embedding should be a fixed-length vector that represents the semantic meaning of a document.
#
# - `threshold`: This is a float value between 0 and 1 that determines the cutoff for considering two documents to be part of the same community. It's based on the cosine similarity of the document embeddings. If the cosine similarity of two document embeddings is greater than the threshold, those two documents are considered to be in the same community. The higher the threshold, the more similar the documents in each community will be. However, a higher threshold may also result in more communities.
#
# - `min_community_size`: This is the minimum number of documents that a community must have. If a community has fewer than this number of documents, it will be discarded. The default value is 1, but you might want to set a higher value if you're interested in larger communities. This can help filter out noise and find more meaningful communities.
#
# - `batch_size`: As the function computes cosine similarities between document pairs, it may consume a significant amount of memory for a large corpus. To manage this, the computations are done in batches. The batch_size parameter determines the number of document pairs to compute similarities for in each batch. Larger batch sizes can be faster but consume more memory, while smaller batch sizes are slower but more memory-efficient.
#
# The function returns a list of communities, where each community is a list of indices in the original list of documents. Each community represents a group of semantically similar documents based on the provided threshold.

# %%
from sentence_transformers.util import community_detection
document_embeddings = model.encode(
    corpus, show_progress_bar=True, convert_to_tensor=True
)
communities = community_detection(
    document_embeddings, threshold=0.5, min_community_size=2, batch_size=1024
)
for i, comm in enumerate(communities):
    print('_'*50)
    print(f'community: {i}, size: {len(comm)}')
    print('\n'.join([corpus[ind] for ind in comm]))
    print()
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# __________________________________________________
# community: 0, size: 4
# Deep learning is a part of machine learning
# Neural networks are used in deep learning
# Machine learning is a subset of AI
# Artificial intelligence is the future
#
# __________________________________________________
# community: 1, size: 3
# Strawberries are red fruits
# The apple is a sweet fruit
# Oranges are citrus fruits
#
# __________________________________________________
# community: 2, size: 3
# Whales are the largest marine mammals
# Elephants are the largest land mammals
# Sharks are marine predators

# %% [markdown]
# In the output, we will see the communities of semantically similar sentences. Note that the choice of the threshold value can greatly affect the results: a lower threshold will result in larger but less cohesive communities, while a higher threshold will result in smaller but more tightly-knit communities.
#
# The community_detection function is a fast and efficient way to group similar sentences together, but keep in mind that it's a rather simple method based on thresholding the cosine similarity, and more sophisticated community detection methods might yield better results for certain tasks or datasets.
#
# This function is a great way to explore the semantic structure of your corpus and to get a high-level understanding of the main themes or topics in your text data.
